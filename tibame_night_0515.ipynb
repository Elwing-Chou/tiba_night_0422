# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tiba_night_0422/blob/main/tibame_night_0515.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req

url = "https://github.com/Elwing-Chou/tiba_night_0422/raw/refs/heads/main/chiikawa.csv"
req.urlretrieve(url, "chiikawa.csv")
# Out:
# ('chiikawa.csv', <http.client.HTTPMessage at 0x7c5d2d75ff10>)

# %%
import pandas as pd
df = pd.read_csv("chiikawa.csv", encoding="utf-8", index_col=0)
df
# Out:
#         text    color  size  position  time        sn      userid
# 0     謝謝巴哈大哥  #FFFFFF     1         0     0  37089407     s970446
# 1        第一次  #FFFFFF     1         0     0  39557840   wex690825
# 2        0.0  #FFFFFF     1         0     0  40729192   z80262001
# 3          耶  #FFFFFF     1         0     0  41875955   ouyang318
# 4         二刷  #FFFFFF     1         0     0  42903755  qaz1210731
# ..       ...      ...   ...       ...   ...       ...         ...
# 494      ZMB  #FFFFFF     1         0   877  42527612     ZED8090
# 495  兄弟有事請轉身  #FFFFFF     1         0   890  44754781    D0690422
# 496        😀  #00C3FC     1         0   898  40894473   kekerry75
# 497   沒了？？？？  #FFFFFF     1         0   901  42188563      linzzi
# 498        哈  #FF0026     1         0   901  44529579   st5109185
#
# [499 rows x 7 columns]

# %%
# and(&) or(|)
fil = (df["time"] > 630) & (df["time"] < 720)
df[fil]

# %%
df["userid"].value_counts()

# %%
fil = (df["userid"] == "annana566")
df[fil]
# Out:
#                        text    color  size  position  time        sn  \
# 143                     好萌喔  #FFFFFF     1         0   191  43650216
# 236                  喔我要不行惹  #FFFFFF     1         0   382  43650219
# 264         鬆餅，你好香( 。ớ ₃ờ)ھ  #FFFFFF     1         0   463  43683890
# 265                 人類：手機先吃  #FFFFFF     1         0   463  43683900
# 266               這食物這算不算SM  #FFFFFF     1         0   463  43683911
# 357   冷知識：已結束，而且片尾很長<(˙▽˙<)  #FFFFFF     1         2   643  43683942
# 481  所以為啥彈幕要一直兄弟的( ･᷄ὢ･᷅ )？  #FFFFFF     1         2   846  43683954
#
#         userid
# 143  annana566
# 236  annana566
# 264  annana566
# 265  annana566
# 266  annana566
# 357  annana566
# 481  annana566
